# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# <h1 align=center><font size = 5>Assignment: Notebook for Peer Assignment</font></h1>

# %% [markdown]
# # Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand three Chicago datasets
# 2.  Load the three datasets into three tables in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Understand the datasets
#
# To complete the assignment problems in this notebook you will be using three datasets that are available on the city of Chicago's Data Portal:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Socioeconomic Indicators in Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Public Schools</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to have these three tables populated with a subset of the whole datasets.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the links below to download and save the datasets (.CSV files):
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Census Data</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Public Schools</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Crime Data</a>
#
# **NOTE:** Ensure you have downloaded the datasets using the links above instead of directly from the Chicago Data Portal. The versions linked here are subsets of the original datasets and have some of the column names modified to be more database friendly which will make it easier to complete this assignment.

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be loaded into SQLite DB.
# We will create three tables in as under:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**
#
# Let us now load the ipython-sql  extension and establish a connection with the database
#
# * Here you will be loading the csv files into the pandas Dataframe and then loading the data into the above mentioned sqlite tables.
#
# * Next you will be connecting to the sqlite database  **FinalDB**.
#
# Refer to the previous lab for hints .
#
# <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing_SQLite.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %%
# !pip install sqlalchemy==2.0.5
# !pip install ipython-sql 
import pandas as pd
# Out:
# Requirement already satisfied: sqlalchemy==2.0.5 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (2.0.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from sqlalchemy==2.0.5) (4.5.0)
# Requirement already satisfied: ipython-sql in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: ipython in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython-sql) (8.11.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython-sql) (2.0.5)
# Requirement already satisfied: sqlparse in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: prettytable in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython-sql) (3.6.0)
# Requirement already satisfied: ipython-genutils in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: six in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.5.0)
# Requirement already satisfied: pexpect>4.3 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: traitlets>=5 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (5.9.0)
# Requirement already satisfied: pickleshare in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (3.0.38)
# Requirement already satisfied: backcall in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: appnope in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (0.1.3)
# Requirement already satisfied: stack-data in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: pygments>=2.4.0 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (2.14.0)
# Requirement already satisfied: decorator in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: wcwidth in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from prettytable->ipython-sql) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: pure-eval in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from stack-data->ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/fuyakoshiro/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from stack-data->ipython->ipython-sql) (2.2.1)

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
print(con)
# Out:
# <sqlite3.Connection object at 0x1160abe40>

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df1 = pd.read_csv("ChicagoCensusData.csv")
df2 = pd.read_csv("ChicagoCrimeData.csv")
df3 = pd.read_csv("ChicagoPublicSchools.csv")

# %%
df1.to_sql("CENSUS", con, if_exists="replace", index=False, method="multi")
df2.to_sql("CRIME", con, if_exists="replace", index=False, method="multi")
df3.to_sql("PUBLICSCHOOLS", con, if_exists="replace", index=False, method="multi")
# Out:
# 566

# %%
df1.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT_AGED_UNDER_18_OR_OVER_64  PER_CAPITA_INCOME  HARDSHIP_INDEX
# 0                              27.5              23939            39.0
# 1                              38.5              23040            46.0
# 2                              22.2              35787            20.0
# 3                              25.5              37524            17.0
# 4                              26.2              57123             6.0

# %%
df2.head(20)
# Out:
#           ID CASE_NUMBER        DATE                     BLOCK IUCR  \
# 0    3512276    HK587712  2004-08-28        047XX S KEDZIE AVE  890
# 1    3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE  820
# 2    8002131    HT233595  2011-04-04        043XX S WABASH AVE  820
# 3    7903289    HT133522  2010-12-30      083XX S KINGSTON AVE  840
# 4   10402076    HZ138551  2016-02-02           033XX W 66TH ST  820
# 5    7732712    HS540106  2010-09-29       006XX W CHICAGO AVE  810
# 6   10769475    HZ534771  2016-11-30        050XX N KEDZIE AVE  810
# 7    4494340    HL793243  2005-12-16       005XX E PERSHING RD  860
# 8    3778925    HL149610  2005-01-28     100XX S WASHTENAW AVE  810
# 9    3324217    HK361551  2004-05-13       033XX W BELMONT AVE  820
# 10   9902691    HX552797  2014-12-23        076XX S CICERO AVE  860
# 11   7947964    HT180228  2011-02-26        012XX S HALSTED ST  820
# 12   8568365    HV243612  2012-04-15       108XX S EMERALD AVE  820
# 13   5343947    HN200365  2007-02-26          011XX S CANAL ST  842
# 14   3121541    HK108680  2003-01-05       038XX W FLOURNOY ST  890
# 15  10209850    HY396729  2015-08-24        026XX N ELSTON AVE  820
# 16   6866556    HR271603  2009-04-16  089XX S STONY ISLAND AVE  860
# 17   9681782    HX332132  2014-07-04          079XX S STATE ST  820
# 18   9166453    HW303994  2013-06-04        055XX W GLADYS AVE  810
# 19   7762423    HS569246  2010-10-17     058XX W ARTHINGTON ST  880
#
#    PRIMARY_TYPE                    DESCRIPTION  \
# 0         THEFT                  FROM BUILDING
# 1         THEFT                 $500 AND UNDER
# 2         THEFT                 $500 AND UNDER
# 3         THEFT  FINANCIAL ID THEFT: OVER $300
# 4         THEFT                 $500 AND UNDER
# 5         THEFT                      OVER $500
# 6         THEFT                      OVER $500
# 7         THEFT                   RETAIL THEFT
# 8         THEFT                      OVER $500
# 9         THEFT                 $500 AND UNDER
# 10        THEFT                   RETAIL THEFT
# 11        THEFT                 $500 AND UNDER
# 12        THEFT                 $500 AND UNDER
# 13        THEFT        AGG: FINANCIAL ID THEFT
# 14        THEFT                  FROM BUILDING
# 15        THEFT                 $500 AND UNDER
# 16        THEFT                   RETAIL THEFT
# 17        THEFT                 $500 AND UNDER
# 18        THEFT                      OVER $500
# 19        THEFT                PURSE-SNATCHING
#
#               LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  DISTRICT  WARD  \
# 0               SMALL RETAIL STORE   False     False  ...         9  14.0
# 1                            OTHER   False     False  ...        11  27.0
# 2     NURSING HOME/RETIREMENT HOME   False     False  ...         2   3.0
# 3                        RESIDENCE   False     False  ...         4   7.0
# 4                            ALLEY   False     False  ...         8  15.0
# 5   PARKING LOT/GARAGE(NON.RESID.)   False     False  ...        12  27.0
# 6                           STREET   False     False  ...        17  33.0
# 7               GROCERY FOOD STORE    True     False  ...         2   3.0
# 8                           STREET   False     False  ...        22  19.0
# 9               SMALL RETAIL STORE   False     False  ...        17  35.0
# 10                DEPARTMENT STORE    True     False  ...         8  13.0
# 11                   BAR OR TAVERN   False     False  ...        12  25.0
# 12   RESIDENTIAL YARD (FRONT/BACK)   False     False  ...        22  34.0
# 13                           OTHER   False     False  ...         1   2.0
# 14         RESIDENCE PORCH/HALLWAY   False     False  ...        11  24.0
# 15  PARKING LOT/GARAGE(NON.RESID.)   False     False  ...        14   1.0
# 16                           OTHER    True     False  ...         4   8.0
# 17                    CTA PLATFORM   False     False  ...         6   6.0
# 18                 VACANT LOT/LAND   False     False  ...        15  29.0
# 19                        SIDEWALK   False     False  ...        15  29.0
#
#     COMMUNITY_AREA_NUMBER  FBICODE X_COORDINATE  Y_COORDINATE  YEAR  \
# 0                    58.0        6    1155838.0     1873050.0  2004
# 1                    23.0        6    1152206.0     1906127.0  2004
# 2                    38.0        6    1177436.0     1876313.0  2011
# 3                    46.0        6    1194622.0     1850125.0  2010
# 4                    66.0        6    1155240.0     1860661.0  2016
# 5                    24.0        6    1171668.0     1905607.0  2010
# 6                    14.0        6    1154133.0     1933314.0  2016
# 7                    38.0        6    1180448.0     1879234.0  2005
# 8                    72.0        6    1160129.0     1838040.0  2005
# 9                    21.0        6    1153590.0     1921084.0  2004
# 10                   65.0        6    1145727.0     1853720.0  2014
# 11                   28.0        6    1171230.0     1894421.0  2011
# 12                   49.0        6    1173239.0     1832994.0  2012
# 13                   28.0        6    1173307.0     1895342.0  2007
# 14                   26.0        6    1150808.0     1896753.0  2003
# 15                   22.0        6    1160867.0     1917657.0  2015
# 16                   48.0        6    1188475.0     1846086.0  2009
# 17                   44.0        6    1177660.0     1852569.0  2014
# 18                   25.0        6    1139693.0     1897797.0  2013
# 19                   25.0        6    1137635.0     1895420.0  2010
#
#      LATITUDE  LONGITUDE                       LOCATION
# 0   41.807440 -87.703956    (41.8074405, -87.703955849)
# 1   41.898280 -87.716406  (41.898279962, -87.716405505)
# 2   41.815933 -87.624642  (41.815933131, -87.624642127)
# 3   41.743665 -87.562463  (41.743665322, -87.562462756)
# 4   41.773455 -87.706480  (41.773455295, -87.706480471)
# 5   41.896447 -87.644939  (41.896446772, -87.644938678)
# 6   41.972845 -87.708600  (41.972844913, -87.708600079)
# 7   41.823880 -87.613504  (41.823879885, -87.613503857)
# 8   41.711281 -87.689179  (41.711280513, -87.689179097)
# 9   41.939296 -87.710923  (41.939295821, -87.710923442)
# 10  41.754593 -87.741529  (41.754592961, -87.741528537)
# 11  41.865761 -87.646876  (41.865761261, -87.646875977)
# 12  41.697154 -87.641316  (41.697154372, -87.641315669)
# 13  41.868243 -87.639224  (41.868242722, -87.639223912)
# 14  41.872584 -87.721786   (41.872584178, -87.72178565)
# 15  41.929744 -87.684274  (41.929743818, -87.684273777)
# 16  41.732731 -87.585114  (41.732730806, -87.585114125)
# 17  41.750772 -87.624538  (41.750772111, -87.624538423)
# 18  41.875659 -87.762569  (41.875659108, -87.762568861)
# 19  41.869174 -87.770182  (41.869173601, -87.770182447)
#
# [20 rows x 21 columns]

# %%
df3.head()
# Out:
#    School_ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School         Street_Address     City State  \
# 0                                 ES        615 W Kemper Pl  Chicago    IL
# 1                                 ES  7511 S South Shore Dr  Chicago    IL
# 2                                 ES     8010 S Kostner Ave  Chicago    IL
# 3                                 ES     4619 S Wolcott Ave  Chicago    IL
# 4                                 HS        3630 S Wells St  Chicago    IL
#
#    ZIP_Code    Phone_Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# 3     60609  (773) 535-4389
# 4     60609  (773) 535-1590
#
#                                                 Link  \
# 0  http://schoolreports.cps.edu/SchoolProgressRep...
# 1  http://schoolreports.cps.edu/SchoolProgressRep...
# 2  http://schoolreports.cps.edu/SchoolProgressRep...
# 3  http://schoolreports.cps.edu/SchoolProgressRep...
# 4  http://schoolreports.cps.edu/SchoolProgressRep...
#
#                       Network_Manager  ... Freshman_on_Track_Rate__  \
# 0        Fullerton Elementary Network  ...                      NDA
# 1           Skyway Elementary Network  ...                      NDA
# 2           Midway Elementary Network  ...                      NDA
# 3         Pershing Elementary Network  ...                      NDA
# 4  Southwest Side High School Network  ...                     91.8
#
#   X_COORDINATE Y_COORDINATE   Latitude  Longitude COMMUNITY_AREA_NUMBER  \
# 0  1171699.458  1915829.428  41.924497 -87.644522                     7
# 1  1196129.985  1856209.466  41.760324 -87.556736                    43
# 2  1148427.165  1851012.215  41.747111 -87.731702                    70
# 3  1164504.290  1873959.199  41.809757 -87.672145                    61
# 4  1175177.622  1880745.126  41.828146 -87.632794                    34
#
#   COMMUNITY_AREA_NAME  Ward Police_District                     Location
# 0        LINCOLN PARK    43              18  (41.92449696, -87.64452163)
# 1         SOUTH SHORE     7               4  (41.76032435, -87.55673627)
# 2             ASHBURN    13               8  (41.74711093, -87.73170248)
# 3            NEW CITY    20               9    (41.8097569, -87.6721446)
# 4       ARMOUR SQUARE    11               9  (41.82814609, -87.63279369)
#
# [5 rows x 78 columns]

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %%sql
# select count(*) from CRIME;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %%sql
# select COMMUNITY_AREA_NAME, PER_CAPITA_INCOME from CENSUS
# where PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes  involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %%sql
# select CASE_NUMBER,PRIMARY_TYPE,DESCRIPTION from CRIME where DESCRIPTION like '%MINOR%' or PRIMARY_TYPE like '%MINOR%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('HL266884', 'LIQUOR LAW VIOLATION', 'SELL/GIVE/DEL LIQUOR TO MINOR'),
#  ('HK238408', 'LIQUOR LAW VIOLATION', 'ILLEGAL CONSUMPTION BY MINOR')]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %%sql
# select * from CRIME where PRIMARY_TYPE = 'KIDNAPPING' and DESCRIPTION like '%CHILD%';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %% [markdown]
# ### Problem 5
#
# ##### What kinds of crimes were recorded at schools?

# %%
# %%sql
# select distinct(PRIMARY_TYPE) from CRIME where LOCATION_DESCRIPTION like '%SCHOOL%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for each type of school.

# %%
# %%sql
# select "Elementary, Middle, or High School", avg(safety_score) as average_safety_score
# from PUBLICSCHOOLS group by "Elementary, Middle, or High School"
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %%sql
# select community_area_name, percent_households_below_poverty from CENSUS
# order by percent_households_below_poverty desc nulls last limit 5;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone?

# %%
# %%sql
# select community_area_name CE from CRIME CR, CENSUS CE group by CE.community_area_name
# order by count(*) desc nulls last limit 1
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) no such column: community_area_name
# [SQL: select community_area_name from CRIME group by community_area_name
# order by count(*) desc nulls last limit 1]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Query for the 'community area number' that is most crime prone.
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %% [markdown]
# Copyright © 2020 This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# ## Author(s)
#
# <h4> Hima Vasudevan </h4>
# <h4> Rav Ahuja </h4>
# <h4> Ramesh Sannreddy </h4>
#
# ## Contribtuor(s)
#
# <h4> Malika Singla </h4>
#
# ## Change log
#
# | Date       | Version | Changed by        | Change Description                             |
# | ---------- | ------- | ----------------- | ---------------------------------------------- |
# | 2022-03-04 | 2.5     | Lakshmi Holla     | Changed markdown.                   |
# | 2021-05-19 | 2.4     | Lakshmi Holla     | Updated the question                           |
# | 2021-04-30 | 2.3     | Malika Singla     | Updated the libraries                          |
# | 2021-01-15 | 2.2     | Rav Ahuja         | Removed problem 11 and fixed changelog         |
# | 2020-11-25 | 2.1     | Ramesh Sannareddy | Updated the problem statements, and datasets   |
# | 2020-09-05 | 2.0     | Malika Singla     | Moved lab to course repo in GitLab             |
# | 2018-07-18 | 1.0     | Rav Ahuja         | Several updates including loading instructions |
# | 2018-05-04 | 0.1     | Hima Vasudevan    | Created initial version                        |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
